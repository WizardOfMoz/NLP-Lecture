# %%
import numpy as np
import pandas as pd
from IPython.display import display
import itertools
import random
from collections import  Counter

df = pd.read_csv('data/A2_dataset_processed.csv', index_col=0)
tweets = df.NEW_TEXT.astype(str).tolist()
tweet_words = [tweet.split() for tweet in tweets]
word_count = Counter(itertools.chain(*tweet_words))
total_tokens = sum(word_count.values())
tweet_bigrams = list(itertools.chain.from_iterable([list(zip(tweet, tweet[1:])) for tweet in tweet_words]))
bigram_count = dict(Counter(tweet_bigrams))
words = sorted(list(set(" ".join(tweets).split(" "))))
word_prob = {word: word_count[word]/total_tokens  for word in words}

# %%
coc_mat = pd.DataFrame(0.0,index=words,columns=words)
for bigram in tweet_bigrams:
    coc_mat.loc[bigram[0],bigram[1]]+=1

prob_mat = coc_mat.div(coc_mat.sum(axis=1), axis=0).fillna(0)

# %% [markdown]
# Highest occuring bigrams

# %%
sorted(bigram_count.items(),key=lambda x: x[1],reverse=True)[:4]
# Out:
# [(('can', 'not'), 170),
#  (('but', 'not'), 49),
#  (('not', 'get'), 48),
#  (('wake', 'up'), 44)]

# %% [markdown]
# Smoothing

# %%
factor = 1*np.array(list(word_prob.values()))
coc_mat_ = coc_mat + factor
smooth_mat = coc_mat_.div(coc_mat_.add(factor).sum(axis=1), axis=0).fillna(0)
smooth_mat
# Out:
#              0      0130        03       030        05      0736      0822  \
# 0     0.000017  0.000017  0.000017  0.000017  0.000017  0.000017  0.000017
# 0130  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# 03    0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# 030   0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# 05    0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# ...        ...       ...       ...       ...       ...       ...       ...
# ñððð  0.000009  0.000009  0.000009  0.000009  0.000009  0.000009  0.000009
# ñðñð  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# ññ    0.000007  0.000007  0.000007  0.000007  0.000007  0.000007  0.000007
# ññðð  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012  0.000012
# ñññ   0.000009  0.000009  0.000009  0.000009  0.000009  0.000009  0.000009
#
#             09    093002         1  ...       ñðµ      ñðµð  ñðµñðµñð  \
# 0     0.000069  0.000017  0.000519  ...  0.000017  0.000017  0.000017
# 0130  0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# 03    0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# 030   0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# 05    0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# ...        ...       ...       ...  ...       ...       ...       ...
# ñððð  0.000035  0.000009  0.000260  ...  0.000009  0.000009  0.000009
# ñðñð  0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# ññ    0.000028  0.000007  0.000208  ...  0.000007  0.000007  0.000007
# ññðð  0.000046  0.000012  0.000346  ...  0.000012  0.000012  0.000012
# ñññ   0.000035  0.000009  0.000260  ...  0.000009  0.000009  0.000009
#
#            ñðð      ñððµ      ñððð      ñðñð        ññ      ññðð       ñññ
# 0     0.000035  0.000017  0.000035  0.000017  0.000052  0.000017  0.000035
# 0130  0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# 03    0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# 030   0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# 05    0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# ...        ...       ...       ...       ...       ...       ...       ...
# ñððð  0.000017  0.000009  0.000017  0.000009  0.000026  0.000009  0.000017
# ñðñð  0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# ññ    0.000014  0.000007  0.000014  0.000007  0.000021  0.000007  0.000014
# ññðð  0.000023  0.000012  0.000023  0.000012  0.000035  0.000012  0.000023
# ñññ   0.000017  0.000009  0.000017  0.000009  0.000026  0.000009  0.000017
#
# [6297 rows x 6297 columns]

# %% [markdown]
# Sentiment Addition

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

def get_sentiment_score(text,scaling_factor=100,sentiment='positive'):
    sid = SentimentIntensityAnalyzer()
    score = scaling_factor*sid.polarity_scores(text)['compound']
    if sentiment =='negative':
        score = -score
    
    if score>=0:
        return score+1
    return 1


def vader_class(sentence):
    sid = SentimentIntensityAnalyzer()
    scores= sid.polarity_scores(sentence)
    return int(scores['compound']>=0)

# %%
word_positive_sentiment = {word:get_sentiment_score(word) for word in words}
word_negative_sentiment = {word:get_sentiment_score(word,sentiment='negative') for word in words}

# %%
bigram_positive_sentiment = {bigram:get_sentiment_score(" ".join(bigram)) for bigram in tweet_bigrams}
bigram_negative_sentiment = {bigram:get_sentiment_score(" ".join(bigram),sentiment='negative') for bigram in tweet_bigrams}

# %%
[key for key in bigram_positive_sentiment.keys() if bigram_positive_sentiment[key]!=bigram_negative_sentiment[key]]
# Out:
# [('like', 'sedan'),
#  ('sooooooooooo', 'tired'),
#  ('tired', 'sparrow'),
#  ('not', 'worry'),
#  ('worry', 'vote'),
#  ('col', 'love'),
#  ('love', 'much'),
#  ('ever', 'good'),
#  ('good', 'love'),
#  ('love', 'knitpicks'),
#  ('sorry', 'not'),
#  ('get', 'ready'),
#  ('ready', 'church'),
#  ('need', 'shake'),
#  ('shake', 'gloomy'),
#  ('gloomy', 'feeling'),
#  ('feeling', 'maybe'),
#  ('anything', 'fun'),
#  ('cheer', 'follow'),
#  ('yea', 'alone'),
#  ('good', 'morning'),
#  ('morning', 'bless'),
#  ('bless', 'another'),
#  ('another', 'share'),
#  ('share', 'light'),
#  ('light', 'love'),
#  ('love', 'others'),
#  ('well', 'thanks'),
#  ('thanks', 'lol'),
#  ('lol', 'want'),
#  ('play', 'against'),
#  ('nothing', 'like'),
#  ('like', 'si'),
#  ('not', 'good'),
#  ('good', 'without'),
#  ('lol', 'help'),
#  ('help', 'assess'),
#  ('hate', 'people'),
#  ('sad', 'iranelection'),
#  ('wah', 'glad'),
#  ('glad', 'cut'),
#  ('cut', 'run'),
#  ('open', 'sentence'),
#  ('sentence', 'describe'),
#  ('answer', 'please'),
#  ('please', 'try'),
#  ('try', 'love'),
#  ('love', 'music'),
#  ('tell', 'please'),
#  ('not', 'forget'),
#  ('lol', 'okay'),
#  ('okay', 'permission'),
#  ('give', 'credit'),
#  ('miss', 'freshman'),
#  ('nice', 'pic'),
#  ('pic', 'like'),
#  ('like', 'shirt'),
#  ('om', 'bad'),
#  ('bad', 'mean'),
#  ('stay', 'like'),
#  ('get', 'wrong'),
#  ('wrong', 'right'),
#  ('poor', 'l'),
#  ('sleepy', 'hate'),
#  ('hate', '8am'),
#  ('moz', 'cancel'),
#  ('cancel', 'poor'),
#  ('poor', 'kill'),
#  ('miss', 'game'),
#  ('seem', 'scare'),
#  ('scare', 'xxx'),
#  ('back', 'wasted'),
#  ('wasted', 'week'),
#  ('student', 'play'),
#  ('play', 'back'),
#  ('930', 'no'),
#  ('no', 'phone'),
#  ('grave', 'junk'),
#  ('morning', 'hide'),
#  ('hide', 'right'),
#  ('right', 'worried'),
#  ('lightning', 'careful'),
#  ('careful', 'georgetta'),
#  ('miss', 'face'),
#  ('stupid', 'keep'),
#  ('completely', 'bore'),
#  ('bore', 'blah'),
#  ('blah', 'need'),
#  ('need', 'hug'),
#  ('want', 'wake'),
#  ('up', 'love'),
#  ('love', 'goo'),
#  ('grumpy', 'guilt'),
#  ('guilt', 'house'),
#  ('office', 'hopefully'),
#  ('hopefully', 'find'),
#  ('find', 'sick'),
#  ('sick', 'hard'),
#  ('hard', 'keep'),
#  ('notice', 'love'),
#  ('love', 'asukaesp'),
#  ('weekday', 'great'),
#  ('great', 'sushi'),
#  ('roll', 'super'),
#  ('super', 'cheap'),
#  ('cheap', 'hope'),
#  ('hope', 'great'),
#  ('great', 'weekend'),
#  ('love', 'think'),
#  ('haha', 'funny'),
#  ('funny', 'reply'),
#  ('reply', 'haha'),
#  ('haha', 'say'),
#  ('kansas', 'appreciate'),
#  ('like', 'death'),
#  ('death', 'next'),
#  ('sleep', 'good'),
#  ('good', '4'),
#  ('cia', 'friend'),
#  ('friend', 'xo'),
#  ('alright', 'finally'),
#  ('time', 'best'),
#  ('best', 'part'),
#  ('bore', 'try'),
#  ('brain', 'dead'),
#  ('dead', 'moment'),
#  ('fair', 'enough'),
#  ('enough', 'slap'),
#  ('slap', 'vi'),
#  ('face', 'okay'),
#  ('okay', 'lmaz'),
#  ('yesterday', 'fantastic'),
#  ('fantastic', 'saw'),
#  ('oregon', 'miss'),
#  ('miss', 'soo'),
#  ('release', 'please'),
#  ('please', 'write'),
#  ('place', 'clean'),
#  ('clean', 'up'),
#  ('full', 'definitely'),
#  ('definitely', 'no'),
#  ('no', 'longer'),
#  ('lip', 'hurt'),
#  ('today', 'well'),
#  ('well', 'world'),
#  ('poop', 'forget'),
#  ('order', 'yay'),
#  ('lol', 'twitter'),
#  ('twitter', 'kill'),
#  ('kill', 'blogger'),
#  ('good', 'probably'),
#  ('try', 'abuse'),
#  ('abuse', 'canât'),
#  ('make', 'laugh'),
#  ('haha', 'leave'),
#  ('leave', 'hull'),
#  ('hull', 'alone'),
#  ('alone', 'mate'),
#  ('gh', 'clean'),
#  ('no', 'want'),
#  ('want', 'upset'),
#  ('someone', 'happy'),
#  ('happy', 'someone'),
#  ('no', 'fear'),
#  ('fear', 'back'),
#  ('back', 'no'),
#  ('no', 'ride'),
#  ('door', 'want'),
#  ('want', 'kfc'),
#  ('sleep', 'lol'),
#  ('no', 'not'),
#  ('well', 'break'),
#  ('lemon', 'drop'),
#  ('grad', 'party'),
#  ('party', '124'),
#  ('after', 'love'),
#  ('love', 'summer'),
#  ('physically', 'pain'),
#  ('pain', 'up'),
#  ('move', 'block'),
#  ('block', '10'),
#  ('song', 'glad'),
#  ('glad', 'fun'),
#  ('down', 'sorry'),
#  ('sorry', 'inconvenience'),
#  ('inconvenience', 'time'),
#  ('nobbbbbyyy', 'lobby'),
#  ('lobby', 'not'),
#  ('tweetdeck', 'stop'),
#  ('stop', 'bath'),
#  ('sicckkkk', 'happy'),
#  ('happy', 'mother'),
#  ('bulimic', 'well'),
#  ('well', 'but'),
#  ('story', 'miss'),
#  ('hell', 'weekend'),
#  ('monday', 'sad'),
#  ('sad', 'sad'),
#  ('sad', 'state'),
#  ('fix', 'crash'),
#  ('crash', 'remove'),
#  ('thanks', 'invite'),
#  ('invite', 'swamp'),
#  ('make', 'leave'),
#  ('leave', 'hopefully'),
#  ('hopefully', 'not'),
#  ('really', 'tired'),
#  ('tired', 'man'),
#  ('get', 'sore'),
#  ('sore', 'head'),
#  ('sadly', '31'),
#  ('much', 'love'),
#  ('love', 'ridiculous'),
#  ('ridiculous', 'completely'),
#  ('night', 'ecstatic'),
#  ('rotflmao', 'math'),
#  ('bath', 'wtf'),
#  ('throne', 'thanks'),
#  ('thanks', 'make'),
#  ('good', 'night'),
#  ('off', 'play'),
#  ('play', 'golf'),
#  ('golf', 'wonderful'),
#  ('wonderful', 'husband'),
#  ('picasso', 'cute'),
#  ('want', 'chinese'),
#  ('really', 'like'),
#  ('like', 'fast'),
#  ('jack', 'cool'),
#  ('cool', 'food'),
#  ('run', 'hide'),
#  ('love', 'andy'),
#  ('soo', 'love'),
#  ('love', 'pink'),
#  ('soo', 'amazing'),
#  ('amazing', 'beautiful'),
#  ('make', 'cry'),
#  ('roommate', 'crap'),
#  ('crap', 'aside'),
#  ('alot', 'miss'),
#  ('miss', 'abi'),
#  ('quite', 'grand'),
#  ('thanks', 'marketing'),
#  ('still', 'hurt'),
#  ('hurt', 'pull'),
#  ('education', 'best'),
#  ('best', 'defense'),
#  ('defense', 'against'),
#  ('kid', 'party'),
#  ('party', 'sun'),
#  ('lucky', 'good'),
#  ('good', 'friend'),
#  ('friend', 'but'),
#  ('but', 'sure'),
#  ('sure', 'already'),
#  ('star', 'play'),
#  ('play', 'far'),
#  ('far', 'aggressive'),
#  ('aggressive', 'try'),
#  ('okay', 'ani'),
#  ('taxis', 'love'),
#  ('love', 'family'),
#  ('think', 'leave'),
#  ('stumbleupon', 'please'),
#  ('please', 'give'),
#  ('cousin', 'cute'),
#  ('cute', 'get'),
#  ('bet', 'mistake'),
#  ('mistake', 'nah'),
#  ('nah', 'not'),
#  ('not', 'surprised'),
#  ('cream', 'party'),
#  ('thanks', 'need'),
#  ('caps', 'fan'),
#  ('fan', 'series'),
#  ('but', 'pay'),
#  ('pay', 'lakers'),
#  ('lakers', 'ill'),
#  ('ill', 'root'),
#  ('get', 'chance'),
#  ('chance', '2'),
#  ('hide', 'kitty'),
#  ('harry', 'block'),
#  ('block', 'away'),
#  ('thank', 'helping'),
#  ('helping', 'kind'),
#  ('prayer', 'friend'),
#  ('friend', 'cheese'),
#  ('cheese', 'lose'),
#  ('lose', 'dad'),
#  ('not', 'happy'),
#  ('happy', 'toy'),
#  ('keep', 'tired'),
#  ('tired', 'gossip'),
#  ('gossip', 'heart'),
#  ('heart', 'break'),
#  ('ed', 'like'),
#  ('like', 'really'),
#  ('really', 'excite'),
#  ('miss', 'baby'),
#  ('sleep', 'grand'),
#  ('grand', 'house'),
#  ('house', 'missing'),
#  ('missing', 'tommy'),
#  ('song', 'stuck'),
#  ('stuck', 'head'),
#  ('thing', 'okay'),
#  ('okay', 'not'),
#  ('not', 'bad'),
#  ('microwave', 'fire'),
#  ('fire', 'not'),
#  ('not', 'allow'),
#  ('allow', '2'),
#  ('thanks', 'pass'),
#  ('word', 'no'),
#  ('no', 'plastic'),
#  ('small', 'problem'),
#  ('problem', 'test'),
#  ('send', 'spam'),
#  ('spam', 'reply'),
#  ('not', 'help'),
#  ('help', 'though'),
#  ('rain', 'good'),
#  ('good', 'cycle'),
#  ('find', 'well'),
#  ('well', 'settle'),
#  ('happy', 'mood'),
#  ('people', 'disappear'),
#  ('disappear', 'absolutely'),
#  ('absolutely', 'screw'),
#  ('screw', 'up'),
#  ('rest', 'stop'),
#  ('stop', 'hate'),
#  ('hate', 'use'),
#  ('enjoy', 'no'),
#  ('no', 'doubt'),
#  ('doubt', 'r'),
#  ('much', 'shit'),
#  ('shit', 'lunch'),
#  ('lunch', 'sick'),
#  ('thanks', 'rude'),
#  ('rude', 'post'),
#  ('last', 'nice'),
#  ('say', 'no'),
#  ('no', 'technical'),
#  ('overhyped', 'certainly'),
#  ('certainly', 'attract'),
#  ('attract', 'spotlight'),
#  ('poor', 'daughter'),
#  ('rock', 'festival'),
#  ('festival', 'weekendhope'),
#  ('not', 'drown'),
#  ('drown', 'get'),
#  ('really', 'want'),
#  ('want', 'maxwell'),
#  ('ticket', 'mad'),
#  ('mad', 'expensive'),
#  ('wish', 'life'),
#  ('think', 'sad'),
#  ('sad', 'miss'),
#  ('miss', '14'),
#  ('barra', 'poor'),
#  ('poor', 'family'),
#  ('need', 'please'),
#  ('please', 'mcflyinmanila'),
#  ('artwork', 'risk'),
#  ('risk', 'game'),
#  ('need', 'good'),
#  ('ready', 'bedmadi'),
#  ('blessing', 'c'),
#  ('1', 'best'),
#  ('best', 'night'),
#  ('life', 'honor'),
#  ('honor', 'meeting'),
#  ('get', 'love'),
#  ('love', 'pro'),
#  ('office', 'cool'),
#  ('hey', 'love'),
#  ('love', 'idea'),
#  ('book', 'amazon'),
#  ('love', 'having'),
#  ('myspace', 'lol'),
#  ('idol', 'sorry'),
#  ('sorry', 'lace'),
#  ('but', 'awesome'),
#  ('awesome', 'voice'),
#  ('compare', 'hope'),
#  ('hope', 'settle'),
#  ('settle', 'number'),
#  ('number', 'three'),
#  ('ng', 'fresh'),
#  ('fresh', 'croissant'),
#  ('spread', 'love'),
#  ('love', 'wave'),
#  ('wow', 'night'),
#  ('night', 'l'),
#  ('l', 'slightly'),
#  ('excited', 'leave'),
#  ('leave', 'alto'),
#  ('but', 'no'),
#  ('no', 'pandora'),
#  ('theatre', 'badly'),
#  ('badly', 'burn'),
#  ('link', 'want'),
#  ('want', 'take'),
#  ('lot', 'easy'),
#  ('easy', 'brain'),
#  ('brain', 'hurt'),
#  ('hurt', 'after'),
#  ('ready', 'andrea'),
#  ('water', 'help'),
#  ('help', 'cookies'),
#  ('something', 'well'),
#  ('well', 'enjoy'),
#  ('enjoy', 'dooobai'),
#  ('nin', 'want'),
#  ('want', 'upload'),
#  ('word', 'grand'),
#  ('grand', 'opening'),
#  ('opening', 'postpone'),
#  ('postpone', 'credit'),
#  ('credit', 'card'),
#  ('find', 'like'),
#  ('like', 'here'),
#  ('here', 'lol'),
#  ('lol', 'wish'),
#  ('wish', 'sat'),
#  ('six', 'lol'),
#  ('lol', 'www'),
#  ('1000', 'help'),
#  ('far', 'badly'),
#  ('badly', 'decomposed'),
#  ('decomposed', 'funny'),
#  ('funny', 'scary'),
#  ('www', 'jealous'),
#  ('jealous', 'sushi'),
#  ('ate', 'spam'),
#  ('spam', 'taste'),
#  ('really', 'good'),
#  ('get', 'fine'),
#  ('fine', 'china'),
#  ('china', 'want'),
#  ('want', 'want'),
#  ('want', 'still'),
#  ('not', 'sure'),
#  ('sure', '3'),
#  ('fact', 'rescue'),
#  ('rescue', 'friend'),
#  ('friend', 'later'),
#  ('later', 'sorry'),
#  ('pay', 'back'),
#  ('nick', 'pay'),
#  ('pay', 'site'),
#  ('but', 'ill'),
#  ('ill', 'make'),
#  ('swear', 'felt'),
#  ('earthquake', 'lol'),
#  ('sick', 'past'),
#  ('glad', 'truck'),
#  ('nchen', 'hail'),
#  ('hail', 'raja'),
#  ('murray', 'seriously'),
#  ('seriously', 'lena'),
#  ('not', 'ready'),
#  ('ready', 'three'),
#  ('week', 'cry'),
#  ('cry', 'much'),
#  ('much', 'lol'),
#  ('lol', 'but'),
#  ('never', 'fear'),
#  ('fear', 'find'),
#  ('oh', 'sick'),
#  ('sick', 'rest'),
#  ('away', 'hope'),
#  ('hope', 'well'),
#  ('well', 'xoxovirginia'),
#  ('realize', 'lose'),
#  ('lose', 'entire'),
#  ('starve', 'but'),
#  ('but', 'exhaust'),
#  ('exhaust', 'get'),
#  ('sashes', 'help'),
#  ('help', 'course'),
#  ('keys', 'thanks'),
#  ('thanks', 'follow'),
#  ('taylor', 'swift'),
#  ('outside', 'like'),
#  ('like', 'rain'),
#  ('skin', 'yes'),
#  ('yes', 'weird'),
#  ('home', 'apologize'),
#  ('apologize', 'late'),
#  ('late', 'tired'),
#  ('tired', 'yell'),
#  ('pass', 'flu'),
#  ('flu', 'others'),
#  ('wow', 'deep'),
#  ('deep', 'battlefield'),
#  ('battlefield', 'beautiful'),
#  ('beautiful', 'inspiration'),
#  ('inspiration', '3'),
#  ('thanks', 'rain'),
#  ('thanks', 'canadian'),
#  ('canadian', 'friend'),
#  ('friend', 'invent'),
#  ('amount', 'problem'),
#  ('problem', 'forget'),
#  ('alot', 'drag'),
#  ('drag', 'away'),
#  ('death', 'bed'),
#  ('make', 'sick'),
#  ('jakarta', 'please'),
#  ('please', 'take'),
#  ('expensive', 'cry'),
#  ('cry', 'whenever'),
#  ('muse', 'no'),
#  ('no', 'lie'),
#  ('happy', 'lowe'),
#  ('lowe', 'finish'),
#  ('deck', 'awesome'),
#  ('may', 'drop'),
#  ('drop', 'around'),
#  ('something', 'wrong'),
#  ('wrong', 'uk2'),
#  ('live', 'support'),
#  ('support', 'offline'),
#  ('offline', 'email'),
#  ('something', 'like'),
#  ('like', 'but'),
#  ('thanks', 'parastoo'),
#  ('parastoo', 'nice'),
#  ('nice', 'friend'),
#  ('friend', 'original'),
#  ('original', 'package'),
#  ('package', 'friend'),
#  ('friend', 'room'),
#  ('summer', 'fantastic'),
#  ('fantastic', 'easy'),
#  ('easy', 'ride'),
#  ('set', 'alarm'),
#  ('alarm', '6am'),
#  ('ride', 'hope'),
#  ('hope', 'get'),
#  ('get', 'easy'),
#  ('easy', 'mile'),
#  ('sad', 'time'),
#  ('start', 'leave'),
#  ('leave', 'bench'),
#  ('bench', 'free'),
#  ('free', 'posits'),
#  ('peer', 'pressure'),
#  ('pressure', 'suckswould'),
#  ('not', 'want'),
#  ('want', 'kid'),
#  ('sorry', 'hear'),
#  ('gt', 'get'),
#  ('but', 'ready'),
#  ('ready', 'let'),
#  ('let', 'good'),
#  ('good', 'time'),
#  ('roll', 'haha'),
#  ('haha', 'take'),
#  ('night', 'love'),
#  ('love', 'poetry'),
#  ('linger', 'bad'),
#  ('bad', 'week'),
#  ('art', 'pretty'),
#  ('pretty', 'quick'),
#  ('help', 'book'),
#  ('best', 'fun'),
#  ('car', 'good'),
#  ('good', 'good'),
#  ('good', 'price'),
#  ('screw', 'read'),
#  ('good', 'luck'),
#  ('luck', 'footage'),
#  ('but', 'true'),
#  ('true', 'winner'),
#  ('winner', 'also'),
#  ('take', 'lose'),
#  ('lose', 'much'),
#  ('much', 'well'),
#  ('clipping', 'nice'),
#  ('nice', 'try'),
#  ('try', 'help'),
#  ('help', 'filter'),
#  ('lmaothat', 'cute'),
#  ('ridiculously', 'sick'),
#  ('sick', 'aaaaaa'),
#  ('miss', 'move'),
#  ('3', 'fun'),
#  ('begin', 'hate'),
#  ('hate', 'perezhilton'),
#  ('perezhilton', 'increase'),
#  ('increase', 'snobbishness'),
#  ('snobbishness', 'stem'),
#  ('rise', 'fame'),
#  ('fame', 'find'),
#  ('new', 'favorite'),
#  ('favorite', 'blogger'),
#  ('thanks', 'boo'),
#  ('thanks', 'play'),
#  ('play', 'helluva'),
#  ('movie', 'enjoy'),
#  ('nap', 'hope'),
#  ('hope', 'not'),
#  ('get', 'sick'),
#  ('sad', 'n'),
#  ('make', 'sad'),
#  ('sad', 'not'),
#  ('not', 'excite'),
#  ('excite', 'meeting'),
#  ('2', 'sad'),
#  ('haha', 'david'),
#  ('yes', 'exactly'),
#  ('consequence', 'like'),
#  ('like', 'human'),
#  ('good', 'afternoon'),
#  ('terrible', 'programme'),
#  ('jeremy', 'vile'),
#  ('even', 'funny'),
#  ('funny', 'haha'),
#  ('lol', 'np'),
#  ('np', 'love'),
#  ('here', 'hope'),
#  ('hope', 'like'),
#  ('like', 'stuff'),
#  ('sadly', 'n'),
#  ('get', 'shocked'),
#  ('shocked', 'baby'),
#  ('get', 'violence'),
#  ('violence', 'bf'),
#  ('wish', 'g'),
#  ('night', 'miss'),
#  ('daughter', 'want'),
#  ('want', 'clean'),
#  ('clean', 'garage'),
#  ('no', 'nothing'),
#  ('parent', 'agree'),
#  ('oh', 'no'),
#  ('no', 'poor'),
#  ('poor', 'dear'),
#  ('dear', 'surgery'),
#  ('surgery', 'sick'),
#  ('sick', 'can'),
#  ('wireless', 'want'),
#  ('having', 'friend'),
#  ('friend', 'hope'),
#  ('hope', 'family'),
#  ('family', 'great'),
#  ('leave', 'letter'),
#  ('hedgehog', 'yay'),
#  ('make', 'strong'),
#  ('strong', 'squash'),
#  ('soo', 'nervous'),
#  ('nervous', 'nd'),
#  ('nobody', 'like'),
#  ('like', 'review'),
#  ('read', 'disappoint'),
#  ('disappoint', 'but'),
#  ('maybe', 'like'),
#  ('like', 'since'),
#  ('make', 'smile'),
#  ('smile', 'comment'),
#  ('well', 'nice'),
#  ('nice', 'make'),
#  ('make', 'friend'),
#  ('break', 'friend'),
#  ('friend', 'redo'),
#  ('good', 'deal'),
#  ('wait', 'leave'),
#  ('sam', 'haha'),
#  ('peel', 'dead'),
#  ('dead', 'skin'),
#  ('love', 'her'),
#  ('good', 'plan'),
#  ('ready', 'super'),
#  ('super', 'tire'),
#  ('color', 'want'),
#  ('want', 'bring'),
#  ('early', 'hope'),
#  ('hope', 'good'),
#  ('good', 'get'),
#  ('back', 'bad'),
#  ('bad', 'can'),
#  ('ready', 'last'),
#  ('sad', 'family'),
#  ('many', 'happy'),
#  ('happy', 'up'),
#  ('afeeee', 'happy'),
#  ('bad', 'sleeve'),
#  ('sleeve', 'fit'),
#  ('sore', 'irritated'),
#  ('irritated', 'eye'),
#  ('online', 'good'),
#  ('good', 'moreover'),
#  ('usual', 'suspect'),
#  ('suspect', 'already'),
#  ('oh', 'want'),
#  ('want', 'but'),
#  ('chance', 'game'),
#  ('like', 'li'),
#  ('hate', 'wake'),
#  ('yay', 'mg'),
#  ('instinct', 'lose'),
#  ('hope', 'pass'),
#  ('wondering', 'hell'),
#  ('hell', 'everybody'),
#  ('next', 'haha'),
#  ('childrens', 'mercy'),
#  ('mercy', 'hospital'),
#  ('whedonverse', 'bloody'),
#  ('bloody', 'board'),
#  ('seem', 'like'),
#  ('like', 'another'),
#  ('not', 'fun'),
#  ('fun', 'really'),
#  ('love', 'novella'),
#  ('no', 'performance'),
#  ('basically', 'love'),
#  ('love', 'metro'),
#  ('want', 'post'),
#  ('summer', 'great'),
#  ('bored', 'beginning'),
#  ('realise', 'definite'),
#  ('definite', 'leaving'),
#  ('time', 'drag'),
#  ('drag', 'even'),
#  ('play', 'fussball'),
#  ('thanks', 'but'),
#  ('really', 'worth'),
#  ('worth', 'give'),
#  ('army', 'god'),
#  ('god', 'hit'),
#  ('lose', 'please'),
#  ('please', 'help'),
#  ('help', 'find'),
#  ('find', 'good'),
#  ('good', 'home'),
#  ('hawaii', 'yes'),
#  ('yes', 'awfully'),
#  ('longyuck', 'warm'),
#  ('warm', 'welcoming'),
#  ('welcoming', 'though'),
#  ('wish', 'live'),
#  ('live', 'haha'),
#  ('haha', 'well'),
#  ('well', 'yea'),
#  ('chance', 'talk'),
#  ('talk', 'thanks'),
#  ('thanks', 'jenny'),
#  ('jenny', 'friend'),
#  ('friend', 'tell'),
#  ('alike', 'haha'),
#  ('haha', 'lol'),
#  ('awesome', 'great'),
#  ('great', 'time'),
#  ('no', 'isnt'),
#  ('isnt', 'adorable'),
#  ('adorable', 'here'),
#  ('gd', 'nice'),
#  ('nice', 'shopping'),
#  ('followfriday', 'blind'),
#  ('blind', 'shout'),
#  ('people', 'like'),
#  ('like', '2'),
#  ('hate', 'phone'),
#  ('phone', 'refuse'),
#  ('form', 'beautiful'),
#  ('beautiful', 'isle'),
#  ('ha', 'yup'),
#  ('yup', 'good'),
#  ('rob', 'always'),
#  ('always', 'rob'),
#  ('rob', 'ss'),
#  ('hm', 'ok'),
#  ('ok', 'way'),
#  ('pay', 'bill'),
#  ('soon', 'cute'),
#  ('cute', 'but'),
#  ('morning', 'like'),
#  ('like', 'nice'),
#  ('nice', 'weather'),
#  ('chicago', 'wish'),
#  ('wish', 'awesome'),
#  ('underwood', 'dream'),
#  ('dream', 'sadespecially'),
#  ('cse', 'laugh'),
#  ('laugh', 'face'),
#  ('sad', 'book'),
#  ('get', 'sweet'),
#  ('sweet', 'tea'),
#  ('love', 'jobs'),
#  ('sure', 'id'),
#  ('furnitureagaintk', 'god'),
#  ('god', '4movers'),
#  ('um', 'thank'),
#  ('thank', 'tested'),
#  ('tested', 'like'),
#  ('like', '17'),
#  ('not', 'number'),
#  ('number', 'phone'),
#  ('storm', 'hope'),
#  ('design', 'hard'),
#  ('really', 'wish'),
#  ('wish', 'not'),
#  ('hope', 'ok'),
#  ('ok', 'needwant'),
#  ('cream', 'top'),
#  ('top', 'tons'),
#  ('meh', 'think'),
#  ('start', 'scare'),
#  ('scare', 'threat'),
#  ('ready', 'wonderful'),
#  ('wonderful', 'sunny'),
#  ('settle', 'great'),
#  ('great', 'victorious'),
#  ('soccer', 'frustration'),
#  ('frustration', 'instead'),
#  ('post', 'welcome'),
#  ('no', 'way'),
#  ('not', 'best'),
#  ('best', 'idea'),
#  ('miss', '2'),
#  ('hmm', 'hard'),
#  ('hard', 'no'),
#  ('no', 'store'),
#  ('time', 'god'),
#  ('god', 'never'),
#  ('haha', 'yes'),
#  ('yes', 'next'),
#  ('self', 'lol'),
#  ('disney', 'haha'),
#  ('friday', 'nice'),
#  ('weather', 'want'),
#  ('want', 'leave'),
#  ('leave', 'early'),
#  ('cloud', 'no'),
#  ('no', 'rain'),
#  ('water', 'shortage'),
#  ('shortage', 'mumbai'),
#  ('miss', 'william'),
#  ('watch', 'good'),
#  ('good', 'old'),
#  ('anything', 'please'),
#  ('excite', 'potential'),
#  ('rerun', 'ftw'),
#  ('await', 'result'),
#  ('pray', 'guy'),
#  ('up', 'cute'),
#  ('cute', 'not'),
#  ('no1', 'wish'),
#  ('wish', 'happy'),
#  ('comic', 'wish'),
#  ('wish', 'draw'),
#  ('sound', 'nasty'),
#  ('nasty', 'sorry'),
#  ('not', 'win'),
#  ('win', 'either'),
#  ('secular', 'ill'),
#  ('ill', 'cu'),
#  ('want', 'shopping'),
#  ('not', 'feeling'),
#  ('feeling', 'lauren'),
#  ('lauren', 'hate'),
#  ('hate', 'right'),
#  ('avoid', 'park'),
#  ('money', 'drag'),
#  ('drag', 'advertising'),
#  ('hhh', 'sweet'),
#  ('sweet', 'smell'),
#  ('afternoon', 'good'),
#  ('good', 'all'),
#  ('good', 'hope'),
#  ('up', 'magnificent'),
#  ('magnificent', 'mile'),
#  ('much', 'fun'),
#  ('fun', 'learn'),
#  ('great', 'idea'),
#  ('let', 'amazing'),
#  ('amazing', 'vid'),
#  ('math', 'help'),
#  ('help', 'smart'),
#  ('1k15k', 'save'),
#  ('save', 'buy'),
#  ('soon', 'annoy'),
#  ('annoy', 'best'),
#  ('best', 'mate'),
#  ('realize', 'no'),
#  ('no', 'job'),
#  ('confuse', 'unfortunate'),
#  ('unfortunate', 'combination'),
#  ('get', 'bore'),
#  ('bore', 'buy'),
#  ('credit', 'liga'),
#  ('liga', 'share'),
#  ('lol', 'actually'),
#  ('start', 'like'),
#  ('like', 'change'),
#  ('good', 'sense'),
#  ('sense', 'humor'),
#  ('room', 'happy'),
#  ('happy', 'revising'),
#  ('revising', 'good'),
#  ('fail', 'exams'),
#  ('corriander', 'die'),
#  ('die', 'water'),
#  ('horrible', 'long'),
#  ('though', 'free'),
#  ('free', 'drink'),
#  ('busy', 'play'),
#  ('play', 'past'),
#  ('hour', 'fine'),
#  ('fine', 'till'),
#  ('happy', 'rain'),
#  ('no', 'kind'),
#  ('kind', 'latelolbut'),
#  ('always', 'no'),
#  ('no', 'homo'),
#  ('aaaaaa', 'lose'),
#  ('lose', 'time'),
#  ('time', 'sad'),
#  ('excite', '3'),
#  ('less', 'thrill'),
#  ('sleep', 'energy'),
#  ('energy', 'level'),
#  ('void', 'help'),
#  ('help', 'lol'),
#  ('house', 'no'),
#  ('no', 'fun'),
#  ('worry', 'beloved'),
#  ('beloved', 'liverpool'),
#  ('drink', 'leave'),
#  ('leave', 'cba'),
#  ('boot', 'want'),
#  ('want', 'lay'),
#  ('omg', 'cool'),
#  ('cool', 'like'),
#  ('oz', 'cut'),
#  ('cut', 'baby'),
#  ('world', 'miss'),
#  ('yay', 'thank'),
#  ('no', 'pause'),
#  ('hire', 'hope'),
#  ('miss', 'hug'),
#  ('honeybunches', 'leave'),
#  ('leave', 'greece'),
#  ('2', 'piss'),
#  ('piss', 'off'),
#  ('off', 'playing'),
#  ('playing', 'though'),
#  ('though', 'sorry'),
#  ('sorry', 'boo'),
#  ('love', 'way'),
#  ('land', 'hate'),
#  ('hate', 'wait'),
#  ('wish', 'london'),
#  ('london', 'like'),
#  ('like', 'big'),
#  ('big', 'dream'),
#  ('dream', 'meet'),
#  ('talk', 'swear'),
#  ('swear', 'never'),
#  ('never', 'fight'),
#  ('fly', 'want'),
#  ('want', 'widespread'),
#  ('people', 'join'),
#  ('join', 'relief'),
#  ('relief', 'haha'),
#  ('love', 'song'),
#  ('song', 'haha'),
#  ('haha', 'halo'),
#  ('find', 'glory'),
#  ('dog', 'strangely'),
#  ('strangely', 'quiet'),
#  ('morning', 'huge'),
#  ('huge', 'hangover'),
#  ('suck', 'delay'),
#  ('delay', 'hop'),
#  ('phone', 'charity'),
#  ('charity', 'bike'),
#  ('wake', 'love'),
#  ('love', 'storm'),
#  ('cook', 'terrific'),
#  ('terrific', 'lunchkudos'),
#  ('head', 'kill'),
#  ('kill', 'make'),
#  ('ready', 'get'),
#  ('nice', 'swear'),
#  ('swear', 'gt'),
#  ('gt', 'studio'),
#  ('glad', 'constant'),
#  ('life', 'sure'),
#  ('sure', 'preciousand'),
#  ('early', 'important'),
#  ('important', 'enjoy'),
#  ('enjoy', 'life'),
#  ('cannot', 'regret'),
#  ('no', 'rub'),
#  ('love', 'jazz'),
#  ...]

# %%
beta1_positive = pd.DataFrame(1.0,index=words,columns=words)
for i,(bigram,sent_score) in enumerate(bigram_positive_sentiment.items()):
    beta1_positive.loc[bigram[0],bigram[1]]=sent_score

beta1_negative = pd.DataFrame(1.0,index=words,columns=words)
for i,(bigram,sent_score) in enumerate(bigram_negative_sentiment.items()):
    beta1_negative.loc[bigram[0],bigram[1]]=sent_score

# %%
beta2_positive = np.array(list(word_positive_sentiment.values()))
beta2_negative = np.array(list(word_negative_sentiment.values()))

# %%
positive_mat = beta1_positive*coc_mat + beta2_positive*np.array(list(word_prob.values()))
negative_mat = beta1_negative*coc_mat + beta2_negative*np.array(list(word_prob.values()))

# %%
prob_positive_mat = positive_mat.div(positive_mat.sum(axis=1), axis=0).fillna(0)
prob_negative_mat = negative_mat.div(negative_mat.sum(axis=1), axis=0).fillna(0)

# %%
def gen_sentence(n,smoothing=False,polarity='neutral'):
    if polarity =='positive':
        mat = prob_positive_mat
    elif polarity =='negative':
        mat = prob_negative_mat
    elif smoothing ==True:
        mat = smooth_mat
    else:
        mat = prob_mat
    word = random.choice(list(words))
    sentence = [word]
    for i in range(n-1):
        word = np.array(words)[np.random.multinomial(1, mat.loc[word])==1][0]
        sentence.append(word)
    return " ".join(sentence)

# %% [markdown]
# Generate 250 positive and 250 negative sentences

# %%
generated_data = pd.DataFrame(columns=['TEXT','LABEL'])
for i in range(250):
    sen = gen_sentence(7,polarity='positive')
    generated_data.loc[i,'TEXT'] = sen
    generated_data.loc[i,'LABEL'] = vader_class(sen)

for i in range(250):
    sen = gen_sentence(7,polarity='negative')
    generated_data.loc[i+250,'TEXT'] = sen
    generated_data.loc[i+250,'LABEL'] = vader_class(sen)

generated_data
# Out:
#                                                   TEXT LABEL
# 0                   hood cheese lose much love goo goo     1
# 1    improvement ear disappear already glorious sun...     1
# 2           presentation care thanks dude ya love pour     1
# 3                     info but true miss lol need help     1
# 4             benjerrys laugh daily love god damn like     1
# ..                                                 ...   ...
# 495         bull faulty battery shit chemical get stop     0
# 496                kathy no bueno time man miss stupid     0
# 497   november 23rd emblem angry never beautiful place     0
# 498         bum hurt after attack migrant student week     0
# 499             chico bore last school sad thing fight     0
#
# [500 rows x 2 columns]

# %%
og_data = pd.DataFrame(columns=['TEXT','LABEL'])
og_data['TEXT']=df['NEW_TEXT']
og_data['LABEL']=df['LABEL']

# %%
og_data
# Out:
#                                                    TEXT  LABEL
# 0                                     get threaded scar      0
# 1                            like sedan mango yesterday      1
# 2     car after shower bed sooooooooooo tired sparro...      1
# 3     actually start afternoon try something wed slo...      1
# 4          www gid not worry vote nonstop col love much      1
# ...                                                 ...    ...
# 4282                        performance clip test shock      1
# 4283           gh no rcn true blood episode demand 1013      0
# 4284            return forest sarah mercy lose key wood      1
# 4285                       proud dad piece keep up papa      1
# 4286  wake up eat pizza breakfast also dentist appoi...      0
#
# [4287 rows x 2 columns]

# %%
combined_data = pd.concat([og_data,generated_data],axis=0).sample(frac=1).reset_index(drop=True)

# %%
combined_data.to_csv('combined_data.csv')

# %%
generated_data.to_csv('generated_data.csv')

# %% [markdown]
# Perplexity calculation

# %%
def calculate_perplexity(sentence):
    words = sentence.split()
    bigrams = list(zip(words,words[1:]))
    prob = 1
    for bigram in bigrams:
        prob = prob*smooth_mat.loc[bigram[0],bigram[1]]
    
    return (1/prob)**(1/len(words))

# %%
average_perplexity = np.mean([calculate_perplexity(sentence) for sentence in generated_data.TEXT])
average_perplexity
# Out:
# 62.21735592764733

# %% [markdown]
# Alternate Approaches

# %%
poor_positive_mat = coc_mat + beta2_positive*np.array(list(word_prob.values()))
poor_negative_mat = coc_mat + beta2_negative*np.array(list(word_prob.values()))


prob_poor_positive_mat = poor_positive_mat.div(poor_positive_mat.sum(axis=1), axis=0).fillna(0)
prob_poor_negative_mat = poor_negative_mat.div(poor_negative_mat.sum(axis=1), axis=0).fillna(0)

# %%
def gen_poor_sentence(n,smoothing=False,polarity='neutral'):
    if polarity =='positive':
        mat = prob_poor_positive_mat
    elif polarity =='negative':
        mat = prob_poor_negative_mat
    elif smoothing ==True:
        mat = smooth_mat
    else:
        mat = prob_mat
    word = random.choice(list(words))
    sentence = [word]
    for i in range(n-1):
        word = np.array(words)[np.random.multinomial(1, mat.loc[word])==1][0]
        sentence.append(word)
    return " ".join(sentence)

# %%
generated_data_poor = pd.DataFrame(columns=['TEXT','LABEL'])
for i in range(250):
    sen = gen_poor_sentence(7,polarity='positive')
    generated_data_poor.loc[i,'TEXT'] = sen
    generated_data_poor.loc[i,'LABEL'] = vader_class(sen)

for i in range(250):
    sen = gen_poor_sentence(7,polarity='negative')
    generated_data_poor.loc[i+250,'TEXT'] = sen
    generated_data_poor.loc[i+250,'LABEL'] = vader_class(sen)

generated_data_poor
# Out:
#                                                TEXT LABEL
# 0        fear find perfect end need rave appreciate     1
# 1                   daw dog die drug sky hope great     1
# 2                  sword friend 2 sleep but hop try     1
# 3             jun wow not easily offend thanks take     1
# 4         case hopefully not up witty hope relaxing     1
# ..                                              ...   ...
# 495   artwork check diner chumsno poor little while     0
# 496  parliament bad bitch cordelia hate home monday     0
# 497     frankly sick get good timefollow fail since     0
# 498       money 55 1 athlete upset disappointed sad     0
# 499          minute indeed last full moon need food     1
#
# [500 rows x 2 columns]

# %%
average_perplexity = np.mean([calculate_perplexity(sentence) for sentence in generated_data_poor.TEXT])
average_perplexity
# Out:
# 202.41238382633253

# %%
generated_data_poor.to_csv('generated_data_poor.csv')

# %%
combined_data_poor = pd.concat([og_data,generated_data_poor],axis=0).sample(frac=1).reset_index(drop=True)
combined_data_poor.to_csv('combined_data_poor.csv')
